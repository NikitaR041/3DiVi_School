# %%
import numpy as np
np.random.random((4,4))
# Out:
# array([[8.62379064e-01, 4.83344634e-01, 6.87302200e-01, 4.52422630e-01],
#        [3.82098283e-01, 1.50096669e-02, 9.68945685e-01, 3.23759994e-01],
#        [3.12438272e-01, 3.59850267e-04, 9.29982258e-01, 6.97319005e-01],
#        [1.54921620e-02, 8.60136924e-01, 6.70661601e-01, 6.71049136e-01]])

# %%
# %timeit np.random.random((100,100))
# Out:
# 166 μs ± 43.5 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
ls
# Out:
#  ��� � ���ன�⢥ D ����� ���� ���� ⮬
#  ��਩�� ����� ⮬�: B4DE-A8F1
#
#  ����ন��� ����� d:\3DiVi
#
# 14.10.2025  00:52    <DIR>          .
# 14.10.2025  00:53             1�936 Practice1.ipynb
#                1 䠩���          1�936 ����
#                1 �����  335�155�769�344 ���� ᢮�����
